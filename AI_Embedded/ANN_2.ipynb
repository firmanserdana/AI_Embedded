# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt

(trainX, trainY), (testX, testY) = mnist.load_data()

img_rows, img_cols = 28, 28

trainX = trainX.reshape(trainX.shape[0], img_rows, img_cols, 1)
testX = testX.reshape(testX.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

trainX = trainX.astype('float32')
testX = testX.astype('float32')

trainX /= 255
testX /= 255

trainY = keras.utils.to_categorical(trainY, 10)
testY = keras.utils.to_categorical(testY, 10)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape = input_shape))
model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), metrics=['accuracy'])
model.fit(trainX, trainY, batch_size=128, epochs=12, verbose=1)
# Out:
# 2022-11-29 10:10:46.011588: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-29 10:10:46.012058: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Epoch 1/100
# 2022-11-29 10:10:46.714439: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-11-29 10:10:47.387021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 10/10 - 1s - loss: 19.6140 - accuracy: 0.1000 - 1s/epoch - 109ms/step
# Epoch 2/100
# 10/10 - 0s - loss: 10.6170 - accuracy: 0.1000 - 104ms/epoch - 10ms/step
# Epoch 3/100
# 10/10 - 0s - loss: 5.2226 - accuracy: 0.1000 - 91ms/epoch - 9ms/step
# Epoch 4/100
# 10/10 - 0s - loss: 2.2210 - accuracy: 0.1000 - 71ms/epoch - 7ms/step
# Epoch 5/100
# 10/10 - 0s - loss: 0.4624 - accuracy: 0.1000 - 63ms/epoch - 6ms/step
# Epoch 6/100
# 10/10 - 0s - loss: 0.1418 - accuracy: 0.1000 - 63ms/epoch - 6ms/step
# Epoch 7/100
# 10/10 - 0s - loss: 0.0116 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 8/100
# 10/10 - 0s - loss: 0.0092 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 9/100
# 10/10 - 0s - loss: 0.0110 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 10/100
# 10/10 - 0s - loss: 0.0087 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 11/100
# 10/10 - 0s - loss: 0.0047 - accuracy: 0.1000 - 62ms/epoch - 6ms/step
# Epoch 12/100
# 10/10 - 0s - loss: 0.0045 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 13/100
# 10/10 - 0s - loss: 0.0042 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 14/100
# 10/10 - 0s - loss: 0.0041 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 15/100
# 10/10 - 0s - loss: 0.0040 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 16/100
# 10/10 - 0s - loss: 0.0040 - accuracy: 0.1000 - 62ms/epoch - 6ms/step
# Epoch 17/100
# 10/10 - 0s - loss: 0.0039 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 18/100
# 10/10 - 0s - loss: 0.0038 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 19/100
# 10/10 - 0s - loss: 0.0038 - accuracy: 0.1000 - 63ms/epoch - 6ms/step
# Epoch 20/100
# 10/10 - 0s - loss: 0.0037 - accuracy: 0.1000 - 64ms/epoch - 6ms/step
# Epoch 21/100
# 10/10 - 0s - loss: 0.0037 - accuracy: 0.1000 - 64ms/epoch - 6ms/step
# Epoch 22/100
# 10/10 - 0s - loss: 0.0035 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 23/100
# 10/10 - 0s - loss: 0.0035 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 24/100
# 10/10 - 0s - loss: 0.0034 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 25/100
# 10/10 - 0s - loss: 0.0034 - accuracy: 0.1000 - 62ms/epoch - 6ms/step
# Epoch 26/100
# 10/10 - 0s - loss: 0.0033 - accuracy: 0.1000 - 69ms/epoch - 7ms/step
# Epoch 27/100
# 10/10 - 0s - loss: 0.0032 - accuracy: 0.1000 - 64ms/epoch - 6ms/step
# Epoch 28/100
# 10/10 - 0s - loss: 0.0033 - accuracy: 0.1000 - 64ms/epoch - 6ms/step
# Epoch 29/100
# 10/10 - 0s - loss: 0.0031 - accuracy: 0.1000 - 63ms/epoch - 6ms/step
# Epoch 30/100
# 10/10 - 0s - loss: 0.0030 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 31/100
# 10/10 - 0s - loss: 0.0030 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 32/100
# 10/10 - 0s - loss: 0.0029 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 33/100
# 10/10 - 0s - loss: 0.0029 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 34/100
# 10/10 - 0s - loss: 0.0028 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 35/100
# 10/10 - 0s - loss: 0.0028 - accuracy: 0.1000 - 65ms/epoch - 7ms/step
# Epoch 36/100
# 10/10 - 0s - loss: 0.0027 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 37/100
# 10/10 - 0s - loss: 0.0026 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 38/100
# 10/10 - 0s - loss: 0.0026 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 39/100
# 10/10 - 0s - loss: 0.0025 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 40/100
# 10/10 - 0s - loss: 0.0024 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 41/100
# 10/10 - 0s - loss: 0.0024 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 42/100
# 10/10 - 0s - loss: 0.0024 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 43/100
# 10/10 - 0s - loss: 0.0022 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 44/100
# 10/10 - 0s - loss: 0.0022 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 45/100
# 10/10 - 0s - loss: 0.0021 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 46/100
# 10/10 - 0s - loss: 0.0021 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 47/100
# 10/10 - 0s - loss: 0.0020 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 48/100
# 10/10 - 0s - loss: 0.0021 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 49/100
# 10/10 - 0s - loss: 0.0019 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 50/100
# 10/10 - 0s - loss: 0.0019 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 51/100
# 10/10 - 0s - loss: 0.0018 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 52/100
# 10/10 - 0s - loss: 0.0017 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 53/100
# 10/10 - 0s - loss: 0.0017 - accuracy: 0.1000 - 62ms/epoch - 6ms/step
# Epoch 54/100
# 10/10 - 0s - loss: 0.0016 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 55/100
# 10/10 - 0s - loss: 0.0016 - accuracy: 0.1000 - 63ms/epoch - 6ms/step
# Epoch 56/100
# 10/10 - 0s - loss: 0.0016 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 57/100
# 10/10 - 0s - loss: 0.0015 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 58/100
# 10/10 - 0s - loss: 0.0015 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 59/100
# 10/10 - 0s - loss: 0.0015 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 60/100
# 10/10 - 0s - loss: 0.0014 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 61/100
# 10/10 - 0s - loss: 0.0013 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 62/100
# 10/10 - 0s - loss: 0.0013 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 63/100
# 10/10 - 0s - loss: 0.0012 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 64/100
# 10/10 - 0s - loss: 0.0012 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 65/100
# 10/10 - 0s - loss: 0.0012 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 66/100
# 10/10 - 0s - loss: 0.0011 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 67/100
# 10/10 - 0s - loss: 0.0011 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 68/100
# 10/10 - 0s - loss: 0.0011 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 69/100
# 10/10 - 0s - loss: 0.0010 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 70/100
# 10/10 - 0s - loss: 9.6847e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 71/100
# 10/10 - 0s - loss: 9.4397e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 72/100
# 10/10 - 0s - loss: 8.9080e-04 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 73/100
# 10/10 - 0s - loss: 8.8939e-04 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 74/100
# 10/10 - 0s - loss: 8.7127e-04 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 75/100
# 10/10 - 0s - loss: 8.1452e-04 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 76/100
# 10/10 - 0s - loss: 8.0506e-04 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 77/100
# 10/10 - 0s - loss: 7.7671e-04 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 78/100
# 10/10 - 0s - loss: 7.1112e-04 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 79/100
# 10/10 - 0s - loss: 6.9998e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 80/100
# 10/10 - 0s - loss: 6.6376e-04 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 81/100
# 10/10 - 0s - loss: 6.5826e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 82/100
# 10/10 - 0s - loss: 6.1638e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 83/100
# 10/10 - 0s - loss: 6.1213e-04 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 84/100
# 10/10 - 0s - loss: 5.6396e-04 - accuracy: 0.1000 - 61ms/epoch - 6ms/step
# Epoch 85/100
# 10/10 - 0s - loss: 5.4832e-04 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 86/100
# 10/10 - 0s - loss: 5.1502e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 87/100
# 10/10 - 0s - loss: 4.9871e-04 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 88/100
# 10/10 - 0s - loss: 4.9037e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 89/100
# 10/10 - 0s - loss: 4.6990e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 90/100
# 10/10 - 0s - loss: 4.4567e-04 - accuracy: 0.1000 - 60ms/epoch - 6ms/step
# Epoch 91/100
# 10/10 - 0s - loss: 4.2485e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 92/100
# 10/10 - 0s - loss: 3.9477e-04 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 93/100
# 10/10 - 0s - loss: 3.8543e-04 - accuracy: 0.1000 - 56ms/epoch - 6ms/step
# Epoch 94/100
# 10/10 - 0s - loss: 3.7389e-04 - accuracy: 0.1000 - 57ms/epoch - 6ms/step
# Epoch 95/100
# 10/10 - 0s - loss: 3.7718e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 96/100
# 10/10 - 0s - loss: 3.2851e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 97/100
# 10/10 - 0s - loss: 3.4348e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Epoch 98/100
# 10/10 - 0s - loss: 3.3201e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 99/100
# 10/10 - 0s - loss: 2.9141e-04 - accuracy: 0.1000 - 58ms/epoch - 6ms/step
# Epoch 100/100
# 10/10 - 0s - loss: 2.7520e-04 - accuracy: 0.1000 - 59ms/epoch - 6ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 24
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-11-29 10:10:54.158900: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 480ms/step
# [[1.0298268]
#  [2.0246725]
#  [3.019517 ]
#  [4.0143623]
#  [5.0092063]
#  [6.004051 ]
#  [6.9988966]
#  [7.993742 ]
#  [8.988587 ]
#  [9.983432 ]]
